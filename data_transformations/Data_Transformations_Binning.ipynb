# %% [markdown]
# # Credit Card Retention Analysis

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.graph_objs as go
from plotly.offline import iplot
sns.set()
pd.options.display.max_columns = 999

# %%
data = pd.read_csv('../data/BankChurners_v2.csv')

# %%
data = data[['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
       'Dependent_count', 'Education_Level', 'Marital_Status',
       'Income_Category', 'Card_Category', 'Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',]]

# %%
data['Education_Level'] = data['Education_Level'].fillna('Unknown')
data['Marital_Status'] = data['Marital_Status'].fillna('Unknown')
data['Income_Category'] = data['Income_Category'].fillna('Unknown')

# %% [markdown]
# ***

# %% [markdown]
# ## Data Transformation: Binning

# %% [markdown]
# To bin our ages, we will need a couple data points: the min and max ages. Let's find those.

# %%
print(data['Customer_Age'].min())
print(data['Customer_Age'].max())
# Out:
# 26
# 73

# %% [markdown]
# For more information, see the documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html).

# %%
bins = [25, 30, 40, 50, 60, 70, 80]
labels = ['20s', '30s', '40s', '50s', '60s', '70s']
data['Customer_Age_bins'] = pd.cut(data['Customer_Age'], bins=bins, labels=labels, include_lowest=True, right=False)

# %%
data[data['Customer_Age']==31]
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 602        90634  Existing Customer            31      M                0
# 808        90840  Existing Customer            31      M                0
# 832        90864  Existing Customer            31      F                0
# 866        90898  Existing Customer            31      M                1
# 1011       91043  Existing Customer            31      M                2
# ...          ...                ...           ...    ...              ...
# 9935       99967  Existing Customer            31      M                1
# 9982      100014  Existing Customer            31      F                1
# 10052     100084  Attrited Customer            31      M                1
# 10069     100101  Existing Customer            31      M                2
# 10097     100129  Existing Customer            31      M                0
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 602        Uneducated        Married     $40K - $60K          Blue
# 808          Graduate        Married     $40K - $60K          Blue
# 832          Graduate        Married  Less than $40K          Blue
# 866           Unknown        Married  Less than $40K          Blue
# 1011       Uneducated        Married  Less than $40K          Blue
# ...               ...            ...             ...           ...
# 9935          College         Single     $40K - $60K          Blue
# 9982          Unknown         Single  Less than $40K          Blue
# 10052   Post-Graduate         Single     $40K - $60K          Blue
# 10069        Graduate         Single  Less than $40K          Blue
# 10097     High School         Single     $40K - $60K          Blue
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 602                22                         3                       3
# 808                21                         3                       3
# 832                22                         3                       3
# 866                36                         3                       3
# 1011               18                         3                       2
# ...               ...                       ...                     ...
# 9935               36                         3                       1
# 9982               18                         3                       1
# 10052              24                         4                       2
# 10069              14                         4                       3
# 10097              25                         3                       2
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 602                        0        4048.0                 1113
# 808                        0        2158.0                 1729
# 832                        2        2917.0                 2127
# 866                        3        1868.0                 1515
# 1011                       4        1438.3                    0
# ...                      ...           ...                  ...
# 9935                       2       11109.0                 2045
# 9982                       3        3399.0                 1800
# 10052                      4        4169.0                  534
# 10069                      3        6933.0                 1870
# 10097                      3        4493.0                 1388
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 602             2935.0                 0.717             1757              45
# 808              429.0                 1.100             1718              42
# 832              790.0                 1.074             1831              36
# 866              353.0                 1.359             2229              35
# 1011            1438.3                 1.561             2789              50
# ...                ...                   ...              ...             ...
# 9935            9064.0                 0.625            13988              92
# 9982            1599.0                 0.752            13148             121
# 10052           3635.0                 0.836             8565              70
# 10069           5063.0                 0.656            15585             115
# 10097           3105.0                 0.795            17744             104
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio Customer_Age_bins
# 602                  0.607                  0.275               30s
# 808                  0.448                  0.801               30s
# 832                  1.000                  0.729               30s
# 866                  0.667                  0.811               30s
# 1011                 1.083                  0.000               30s
# ...                    ...                    ...               ...
# 9935                 0.840                  0.184               30s
# 9982                 0.806                  0.530               30s
# 10052                0.795                  0.128               30s
# 10069                0.917                  0.270               30s
# 10097                0.763                  0.309               30s
#
# [91 rows x 22 columns]
